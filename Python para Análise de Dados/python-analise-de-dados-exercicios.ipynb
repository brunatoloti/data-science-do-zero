# %% [markdown]
# # Python para Análise de Dados - Exercícios

# %% [markdown]
# <font color=blue><b> Data Science do Zero </b></font><br>
#  www.minerandodados.com.br

# %% [markdown]
# 1) Importe a biblioteca Pandas

# %%
import pandas as pd

# %% [markdown]
# 2) Leia a base de dados **kc_house_data.csv** localizada no diretorio **datasets** e crie um Dataframe chamado **df**.

# %%
df = pd.read_csv('dados/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# 3) Utilizando o Dataframe criado faça:
# - a) Conte a quantidade de linhas.
# - b) Imprima as informações do Dataframe.
# - c) Imprima o nome das colunas do Dataframe.
# - d) Imprima as informações estatisticas da coluna **bedrooms**.
# - e) Imprima os valores únicos da coluna **bedrooms**.
# - f) Imprima o valor médio da coluna **bathrooms**.

# %%
print(f"A quantidade de linhas do dataframe é: {df.shape[0]}")
# Out:
# A quantidade de linhas do dataframe é: 21613

# %%
print("As informações do dataframe:")
print("\n")
df.info()
# Out:
# As informações do dataframe:
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21609 non-null  float64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21612 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(6), int64(14), object(1)
# memory usage: 3.5+ MB

# %%
print(f"Os nomes das colunas do dataframe: \n\n{df.columns}")
# Out:
# Os nomes das colunas do dataframe:
#
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
print(f"As informções estatísticas da coluna bedrooms: \n\n{df['bedrooms'].describe()}")
# Out:
# As informções estatísticas da coluna bedrooms:
#
# count    21609.000000
# mean         3.370910
# std          0.930084
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %%
print(f"Os valores únicos da coluna bedrooms: \n\n {df['bedrooms'].unique()}")
# Out:
# Os valores únicos da coluna bedrooms:
#
#  [ 3.  2.  4.  5. nan  1.  6.  7.  0.  8.  9. 11. 10. 33.]

# %%
print(f"O valor médio da coluna bathrooms: \n\n {df['bathrooms'].mean()}")
# Out:
# O valor médio da coluna bathrooms:
#
#  2.1147573219821405

# %% [markdown]
# 3) Some a quantidade de valores nulos de cada coluna do Dataframe.

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         4
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           1
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# 4) Remova as linhas onde tenha pela menos um registro faltante em algum atributo.

# %%
df.dropna()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21608 rows x 21 columns]

# %% [markdown]
# 5) Preencha com 1 os values null da coluna bedrooms.

# %%
df['bedrooms'] = df['bedrooms'].fillna(1)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
#Verificando que foram preenchidos os valores null. Lembrando que antes havia 4 valores null na coluna bedrooms

df.bedrooms.isnull().sum()
# Out:
# 0

# %% [markdown]
# 6) Com os seus conhecimentos em consultas faça:
# - a) Retorne todos os imoveis que tenham o número de **bathrooms maior que 1**.
# - b) Retorne todos os imoveis que tenham a quantidade **de bedrooms igual a 4**.
# - c) Conte o retorno da consulta anterior.
# - d) Ordena o Dataframe pela coluna **price** em **ordem decrescente**.
# - e) Agrupe e conte quantidade de imóveis por tamanho de quartos.

# %%
print("Retornando todos os imóveis que possuam número de banheiros maior que 1: ")
df.query("bathrooms > 1")
# Out:
# Retornando todos os imóveis que possuam número de banheiros maior que 1:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0       3.0       2.25
# 3      2487200875  20141209T000000   604000.0       4.0       3.00
# 4      1954400510  20150218T000000   510000.0       3.0       2.00
# 5      7237550310  20140512T000000  1225000.0       4.0       4.50
# 6      1321400060  20140627T000000   257500.0       3.0       2.25
# ...           ...              ...        ...       ...        ...
# 21606  7936000429  20150326T000000  1007500.0       4.0       3.50
# 21607  2997800021  20150219T000000   475000.0       3.0       2.50
# 21608   263000018  20140521T000000   360000.0       3.0       2.50
# 21609  6600060120  20150223T000000   400000.0       4.0       2.50
# 21611   291310100  20150116T000000   400000.0       3.0       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# 5             5420    101930     1.0           0     0  ...     11
# 6             1715      6819     2.0           0     0  ...      7
# ...            ...       ...     ...         ...   ...  ...    ...
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21611         1600      2388     2.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 1            2170            400      1951          1991    98125  47.7210
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# 5            3890           1530      2001             0    98053  47.6561
# 6            1715              0      1995             0    98003  47.3097
# ...           ...            ...       ...           ...      ...      ...
# 21606        2600            910      2009             0    98136  47.5537
# 21607        1180            130      2008             0    98116  47.5773
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21611        1600              0      2004             0    98027  47.5345
#
#           long  sqft_living15  sqft_lot15
# 1     -122.319           1690        7639
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# 5     -122.005           4760      101930
# 6     -122.327           2238        6819
# ...        ...            ...         ...
# 21606 -122.398           2050        6200
# 21607 -122.409           1330        1265
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21611 -122.069           1410        1287
#
# [17675 rows x 21 columns]

# %%
print("Retornando todos os imóveis com 4 quartos: ")
df.query("bedrooms == 4")
# Out:
# Retornando todos os imóveis com 4 quartos:
#                id             date      price  bedrooms  bathrooms  \
# 3      2487200875  20141209T000000   604000.0       4.0       3.00
# 5      7237550310  20140512T000000  1225000.0       4.0       4.50
# 15     9297300055  20150124T000000   650000.0       4.0       3.00
# 17     6865200140  20140529T000000   485000.0       4.0       1.00
# 20     6300500875  20140514T000000   385000.0       4.0       1.75
# ...           ...              ...        ...       ...        ...
# 21598  8956200760  20141013T000000   541800.0       4.0       2.50
# 21599  7202300110  20140915T000000   810000.0       4.0       3.00
# 21605  3448900210  20141014T000000   610685.0       4.0       2.50
# 21606  7936000429  20150326T000000  1007500.0       4.0       3.50
# 21609  6600060120  20150223T000000   400000.0       4.0       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3             1960      5000     1.0           0     0  ...      7
# 5             5420    101930     1.0           0     0  ...     11
# 15            2950      5000     2.0           0     3  ...      9
# 17            1600      4300     1.5           0     0  ...      7
# 20            1620      4980     1.0           0     0  ...      7
# ...            ...       ...     ...         ...   ...  ...    ...
# 21598         3118      7866     2.0           0     2  ...      9
# 21599         3990      7838     2.0           0     0  ...      9
# 21605         2520      6023     2.0           0     0  ...      9
# 21606         3510      7200     2.0           0     0  ...      9
# 21609         2310      5813     2.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3            1050            910      1965             0    98136  47.5208
# 5            3890           1530      2001             0    98053  47.6561
# 15           1980            970      1979             0    98126  47.5714
# 17           1600              0      1916             0    98103  47.6648
# 20            860            760      1947             0    98133  47.7025
# ...           ...            ...       ...           ...      ...      ...
# 21598        3118              0      2014             0    98001  47.2931
# 21599        3990              0      2003             0    98053  47.6857
# 21605        2520              0      2014             0    98056  47.5137
# 21606        2600            910      2009             0    98136  47.5537
# 21609        2310              0      2014             0    98146  47.5107
#
#           long  sqft_living15  sqft_lot15
# 3     -122.393           1360        5000
# 5     -122.005           4760      101930
# 15    -122.375           2140        4000
# 17    -122.343           1610        4300
# 20    -122.341           1400        4980
# ...        ...            ...         ...
# 21598 -122.264           2673        6500
# 21599 -122.046           3370        6814
# 21605 -122.167           2520        6023
# 21606 -122.398           2050        6200
# 21609 -122.362           1830        7200
#
# [6881 rows x 21 columns]

# %%
print(f"Contando o retorno da consulta anterior:\n\n {df.query('bedrooms == 4').count()}")
# Out:
# Contando o retorno da consulta anterior:
#
#  id               6881
# date             6881
# price            6881
# bedrooms         6881
# bathrooms        6881
# sqft_living      6881
# sqft_lot         6881
# floors           6881
# waterfront       6881
# view             6881
# condition        6881
# grade            6881
# sqft_above       6881
# sqft_basement    6881
# yr_built         6881
# yr_renovated     6881
# zipcode          6881
# lat              6881
# long             6881
# sqft_living15    6881
# sqft_lot15       6881
# dtype: int64

# %%
print("Ordenando o dataframe pela coluna price em ordem decrescente:")
df.sort_values(by='price', ascending=False)
# Out:
# Ordenando o dataframe pela coluna price em ordem decrescente:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0       6.0       8.00
# 3914   9808700762  20140611T000000  7062500.0       5.0       4.50
# 9254   9208900037  20140919T000000  6885000.0       6.0       7.75
# 4411   2470100110  20140804T000000  5570000.0       5.0       5.75
# 1448   8907500070  20150413T000000  5350000.0       5.0       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0       3.0       1.00
# 16198  3028200080  20150324T000000    81000.0       2.0       1.00
# 465    8658300340  20140523T000000    80000.0       1.0       0.75
# 15293    40000362  20140506T000000    78000.0       2.0       1.00
# 1149   3421079032  20150217T000000    75000.0       1.0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# 3914         10040     37325     2.0           1     2  ...     11
# 9254          9890     31374     2.0           0     4  ...     13
# 4411          9200     35069     2.0           0     0  ...     13
# 1448          8000     23985     2.0           0     4  ...     12
# ...            ...       ...     ...         ...   ...  ...    ...
# 8274           860     10426     1.0           0     0  ...      6
# 16198          730      9975     1.0           0     0  ...      5
# 465            430      5050     1.0           0     0  ...      4
# 15293          780     16344     1.0           0     0  ...      5
# 1149           670     43377     1.0           0     0  ...      3
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 7252         8570           3480      1910          1987    98102  47.6298
# 3914         7680           2360      1940          2001    98004  47.6500
# 9254         8860           1030      2001             0    98039  47.6305
# 4411         6200           3000      2001             0    98039  47.6289
# 1448         6720           1280      2009             0    98004  47.6232
# ...           ...            ...       ...           ...      ...      ...
# 8274          860              0      1954             0    98146  47.4987
# 16198         730              0      1943             0    98168  47.4808
# 465           430              0      1912             0    98014  47.6499
# 15293         780              0      1942             0    98168  47.4739
# 1149          670              0      1966             0    98022  47.2638
#
#           long  sqft_living15  sqft_lot15
# 7252  -122.323           3940        8800
# 3914  -122.214           3930       25449
# 9254  -122.240           4540       42730
# 4411  -122.233           3560       24345
# 1448  -122.220           4600       21750
# ...        ...            ...         ...
# 8274  -122.341           1140       11250
# 16198 -122.315            860        9000
# 465   -121.909           1200        7500
# 15293 -122.280           1700       10387
# 1149  -121.906           1160       42882
#
# [21613 rows x 21 columns]

# %%
print("Agrupando e contando a quantidade de imóveis por número de quartos:")
df['bedrooms'].value_counts()
# Out:
# Agrupando e contando a quantidade de imóveis por número de quartos:
# 3.0     9822
# 4.0     6881
# 2.0     2759
# 5.0     1601
# 6.0      272
# 1.0      203
# 7.0       38
# 8.0       13
# 0.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# 33.0       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# 7) Crie uma coluna que seja a soma das colunas **bathrooms** e **bedrooms** com o nome **comodos**

# %%
df['comodos'] = df['bathrooms'] + df['bedrooms']
df[['bathrooms', 'bedrooms', 'comodos']].head()
# Out:
#    bathrooms  bedrooms  comodos
# 0       1.00       3.0     4.00
# 1       2.25       3.0     5.25
# 2       1.00       2.0     3.00
# 3       3.00       4.0     7.00
# 4       2.00       3.0     5.00

# %% [markdown]
# 8) Visualize em formato de **histograma** a distribuição dos imoveis por preço.

# %%
df['price'].hist(bins=30, figsize=(10,6))

# %% [markdown]
# 9) Visualize em formato disperção os imoveis utilizando as colunas **bathrooms** e **price**.

# %%
import matplotlib.pyplot as plt

x = df['bathrooms']
y = df['price']


plt.scatter(x, y)
plt.xlabel('# bathrooms')
plt.ylabel('price')
plt.show()

# %% [markdown]
# 10) Gere uma **planilha do Excel** a partir do Dataframe criado.

# %%
df.to_csv('dados/new_kc_house_data.csv', index=False)
